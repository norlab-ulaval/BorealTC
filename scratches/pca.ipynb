# %%
from itertools import chain
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.decomposition import PCA

# from sklearn.preprocessing import StandardScaler
# from imblearn.over_sampling import SMOTE
from utils import preprocessing, transforms

# %%
# Define channels
columns = {
    "imu": {
        "wx": True,
        "wy": True,
        "wz": True,
        "ax": True,
        "ay": True,
        "az": True,
    },
    "pro": {
        "velL": True,
        "velR": True,
        "curL": True,
        "curR": True,
    },
}
summary = pd.DataFrame({"columns": pd.Series(columns)})

husky_summ = summary.copy()
vulpi_summ = summary.copy()

# Get recordings
husky_dfs = preprocessing.get_recordings(Path("norlab-data"), husky_summ)
vulpi_dfs = preprocessing.get_recordings(Path("data"), vulpi_summ)

# %%
husky_merged = preprocessing.merge_upsample(husky_dfs, husky_summ, mode="last")
vulpi_merged = preprocessing.merge_upsample(vulpi_dfs, vulpi_summ, mode="last")

merged = pd.concat([husky_merged, vulpi_merged], ignore_index=True).drop(
    columns=["run_idx"]
)

# %%
terrains = sorted(merged.terrain.unique().tolist())
terr_idx = {t: i for i, t in enumerate(terrains)}

# %%
merged
# Out:
#          time        wx        wy        wz        ax        ay         az  \
# 0        0.00 -0.005036  0.005379  0.006667 -0.194197  1.946763   9.623114
# 1        0.01  0.000888  0.003693  0.003661 -0.818433  1.419832   9.545463
# 2        0.02 -0.001519 -0.000742 -0.000283 -1.026685  1.943875   9.669002
# 3        0.03 -0.001207 -0.000813 -0.006225 -0.815740  1.604288   9.648260
# 4        0.04  0.002333 -0.002882 -0.002515 -0.649156  1.733515   9.649873
# ...       ...       ...       ...       ...       ...       ...        ...
# 754654  66.44 -0.038713 -0.001627 -0.014837  0.721190  0.659949   9.322699
# 754655  66.46 -0.060777  0.043813 -0.038738  0.364944  0.211286   8.801906
# 754656  66.48 -0.088047  0.078721 -0.053959 -0.035684  0.133479   9.381558
# 754657  66.50 -0.068403  0.120071 -0.068097 -0.358337  0.275378  10.305112
# 754658  66.52 -0.125983  0.105214 -0.048980 -0.329143  0.588106  10.445333
#
#            terrain      velL      velR  curL  curR
# 0          ASPHALT  0.196850  0.196850  0.86  0.59
# 1          ASPHALT  0.196850  0.196850  0.86  0.59
# 2          ASPHALT  0.196850  0.196850  0.86  0.59
# 3          ASPHALT  0.196850  0.196850  0.86  0.59
# 4          ASPHALT  0.196850  0.196850  0.86  0.59
# ...            ...       ...       ...   ...   ...
# 754654  UNPLOUGHED  0.581542  0.561845  3.88  2.69
# 754655  UNPLOUGHED  0.581542  0.561845  3.88  2.69
# 754656  UNPLOUGHED  0.677719  0.449882  6.76  0.99
# 754657  UNPLOUGHED  0.677719  0.449882  6.76  0.99
# 754658  UNPLOUGHED  0.677719  0.449882  6.76  0.99
#
# [754659 rows x 12 columns]

# %%
from utils.constants import PLOTCOLORS

IGNORED = ["time", "terrain"]
X_cols = [c for c in merged.columns if c not in IGNORED]

data = merged[X_cols].copy()
target = merged.terrain.copy()
target_idx = target.apply(lambda x: terr_idx[x])

labels = [lab.replace("_", " ") for lab in terrains]
labels = [lab.title() for lab in labels]
label_col = [PLOTCOLORS[lab.lower()] for lab in labels]

target_lab = target_idx.apply(lambda x: labels[x])
target_col = target_idx.apply(lambda x: label_col[x])

# %%
X_reduced = PCA(n_components=3).fit_transform(data.to_numpy())

# %%
import mpl_toolkits.mplot3d

fig = plt.figure(1, figsize=(8, 6))
ax = fig.add_subplot(
    111,
    projection="3d",
    # elev=0,
    # azim=-180,
)

for terr in sorted(target_lab.unique()):
    terr_mask = target_lab == terr
    terr_idx = labels.index(terr)
    if terr in ["Snow", "Asphalt", "Sandy Loam"]:
        continue
    ax.scatter(
        X_reduced[terr_mask, 0],
        X_reduced[terr_mask, 1],
        X_reduced[terr_mask, 2],
        c=label_col[terr_idx],
        label=labels[terr_idx],
        s=0.05,
        alpha=0.5,
    )

ax.set_title("First three PCA dimensions")
ax.set_xlabel("1st Eigenvector")
# ax.xaxis.set_ticklabels([])
ax.set_ylabel("2nd Eigenvector")
# ax.yaxis.set_ticklabels([])
ax.set_zlabel("3rd Eigenvector")
# ax.zaxis.set_ticklabels([])

ax.legend(
    bbox_to_anchor=(1.2, 0.5),
    loc="center left",
    markerscale=40,
    # markeralpha=1,
)

# %%
fig, ax = plt.subplots()
for terr in sorted(target_lab.unique()):
    if terr in ["Snow", "Asphalt"]:
        continue
    terr_mask = target_lab == terr
    terr_idx = labels.index(terr)
    ax.scatter(
        X_reduced[terr_mask, 0],
        X_reduced[terr_mask, 1],
        c=label_col[terr_idx],
        label=labels[terr_idx],
        s=0.05,
        alpha=0.2,
    )

ax.set_title("First two PCA dimensions")
ax.set_xlabel("1st Eigenvector")
ax.xaxis.set_ticklabels([])
ax.set_ylabel("2nd Eigenvector")
ax.yaxis.set_ticklabels([])

ax.legend(
    loc="center left",
    bbox_to_anchor=(1.05, 0.5),
    markerscale=40,
)
